# %% [markdown]
# # Stack Overflow dataset analysis
#
# This notebook uses the MSR2021Replication scripts to run an analysis on other StackOverflow datasets, using the Mallet tool to analyze and cluster the dataset into a predetermined number of topics. This notebook aims to simplify the use of those scripts and make them more understandable and possible to be used in other datasets.

# %% [markdown]
# ## Install python libraries
#
# The notebook's first step is installing the libraries used on the scripts.

# %%
# !pip3 install -r notebook/requirements.txt
# Out:
# WARNING: pip is being invoked by an old script wrapper. This will fail in a future version of pip.
# Please see https://github.com/pypa/pip/issues/5599 for advice on fixing the underlying issue.
# To avoid this problem you can invoke Python with '-m pip' instead of running pip directly.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: nltk in /home/nailliW/.local/lib/python3.7/site-packages (from -r notebook/requirements.txt (line 1)) (3.8.1)
# Requirement already satisfied: pandas in /home/nailliW/.local/lib/python3.7/site-packages (from -r notebook/requirements.txt (line 2)) (1.3.5)
# Requirement already satisfied: click in /home/nailliW/.local/lib/python3.7/site-packages (from nltk->-r notebook/requirements.txt (line 1)) (8.1.7)
# Requirement already satisfied: joblib in /home/nailliW/.local/lib/python3.7/site-packages (from nltk->-r notebook/requirements.txt (line 1)) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /home/nailliW/.local/lib/python3.7/site-packages (from nltk->-r notebook/requirements.txt (line 1)) (2024.4.16)
# Requirement already satisfied: tqdm in /home/nailliW/.local/lib/python3.7/site-packages (from nltk->-r notebook/requirements.txt (line 1)) (4.66.4)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/nailliW/.local/lib/python3.7/site-packages (from pandas->-r notebook/requirements.txt (line 2)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2017.3 in /home/nailliW/.local/lib/python3.7/site-packages (from pandas->-r notebook/requirements.txt (line 2)) (2024.1)
# Requirement already satisfied: numpy>=1.17.3 in /home/nailliW/.local/lib/python3.7/site-packages (from pandas->-r notebook/requirements.txt (line 2)) (1.21.6)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.7.3->pandas->-r notebook/requirements.txt (line 2)) (1.12.0)
# Requirement already satisfied: importlib-metadata in /home/nailliW/.local/lib/python3.7/site-packages (from click->nltk->-r notebook/requirements.txt (line 1)) (6.7.0)
# Requirement already satisfied: zipp>=0.5 in /home/nailliW/.local/lib/python3.7/site-packages (from importlib-metadata->click->nltk->-r notebook/requirements.txt (line 1)) (3.15.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /home/nailliW/.local/lib/python3.7/site-packages (from importlib-metadata->click->nltk->-r notebook/requirements.txt (line 1)) (4.7.1)

# %%
import nltk

nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /home/nailliW/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/nailliW/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %% [markdown]
# Import the notebook scripts to this notebook.

# %%
import sys
sys.path.insert(0, 'notebook/')

# %% [markdown]
# ## Export variables
#
# To customize the scripts to the correct dataset and output path, configure the environment variables to use the path for your dataset and configure the output folder.

# %%
# Export path to the raw dataset
# %env DATASET_PATH=./tcc/so_questions.csv

# Export the output path
# %env OUTPUT_PATH=./output

# Export the number of topics division
# %env TOPICS_NUM=15
# Out:
# env: DATASET_PATH=./tcc/so_questions.csv
# env: OUTPUT_PATH=./output
# env: TOPICS_NUM=15

# %% [markdown]
# ## Prepare dataset for Mallet
#
# The following scripts cleans the StackOverflow dataset and prepare the documents where the Mallet tool will execute the algorithm to separate the topics.

# %%
from clean_stackoverflow_data import clean_so_data
from export_so_to_mallet import export_to_mallet

print('Cleaning dataset...')
clean_so_data()

print('Exporting documents to Mallet...')
export_to_mallet()
print('Done!')
# Out:
# Cleaning dataset...
# ./tcc/so_questions.csv
# Loaded CSV!
# Removed HTML tags!
# Removed stopwords!
# Saved new csv!
# Exporting documents to Mallet...
# Done!

# %% [markdown]
# ## Run the Mallet Tool
#
# The next step is to run the Mallet tool. The mallet commands are using the environment variables set in the beggining of this notebook.

# %%
# !mallet/mallet-2.0.8/bin/mallet import-dir --input $OUTPUT_PATH/so_data/ --output $OUTPUT_PATH/so.mallet --keep-sequence --remove-stopwords --extra-stopwords extra_stop_words/so.txt
# Out:
# Labels =
#    ./output/so_data/

# %%
# !mallet/mallet-2.0.8/bin/mallet train-topics --random-seed 100 --input $OUTPUT_PATH/so.mallet --num-topics 15 --optimize-interval 20 --output-state $OUTPUT_PATH/so-topic-state.gz --output-topic-keys $OUTPUT_PATH/so_keys.txt --output-doc-topics $OUTPUT_PATH/so_composition.txt --diagnostics-file $OUTPUT_PATH/so_diagnostics.xml
# Out:
# Mallet LDA: 15 topics, 4 topic bits, 1111 topic mask
# Data loaded.
# max tokens: 239
# total tokens: 1891
# <10> LL/token: -7.81783
# <20> LL/token: -7.73297
# <30> LL/token: -7.60891
# <40> LL/token: -7.57648
#
# 0	0.33333	dependency await adminsiteotprequired difference system ensure leak otpadminsite import reading understanding development surrounding tool implicit tf_urls urlpatterns class understand execution
# 1	0.33333	environment file variable profile question env hard write load serve order process twelve-factor supply app.web.port app.db.conn prod database follow create
# 2	0.33333	developing based pas list command current driver linux native testing theory aware repository design accept swift team quot branch advance
# 3	0.33333	user authentication login idea json private python workflow enable jbutton username box admin gdrive browser access small failed ci/cd stuff
# 4	0.33333	release build run quot stage apply web simply give key sound define method change impossible runtime recommended http convoluted uniquely
# 5	0.33333	project isolation property deploy application.properties docker parameter specific configurable inside manifesto run application-.properties empty nodejs achieve familiar concept node container
# 6	0.33333	service manage condition work account backend find token process page preview live remoteconfig java secret google system default nfs/network match
# 7	0.33333	quot int amp info_ptr scale authenticator code qrsize const method set std uristream ability generated totp image machine day make
# 8	0.33333	n't make django conf_url thing running configure dev root deploying local practice copy boot spring send location progress adding duplication
# 9	0.33333	png_ptr newqrsize qrcode string otp row null bool encodedstring ckcrypt return module png_bytep strotp base success inputdata crypt otpauth generates
# 10	0.33333	config host stored celery task server answer figure approach read unit possibility place stuck called store intellij computed snapshot previous
# 11	0.33333	deployment firebase channel recipe notebook frontend heroku successfully colab endpoint api wondering personal nginx custom remote add ready angular configs
# 12	0.33333	code setting file bar foo password option support single user devs recommend username doc good coded url working benefit applying
# 13	0.33333	configuration production level vps feature methodology contradictory problem exists made platform managed form shooting prevent instance quick logging devs limit
# 14	0.33333	github test_service_port variable recovery port set tcp container assistant locked documentation checked kubernetes cloud hint greatly mad community finally asks
#
# <50> LL/token: -7.5025
# <60> LL/token: -7.48766
# <70> LL/token: -7.43997
# <80> LL/token: -7.41978
# <90> LL/token: -7.40782
#
# 0	0.33333	dependency isolation adminsiteotprequired difference import ensure leak otpadminsite reading understanding surrounding tool implicit tf_urls urlpatterns class achieve factor-app understand correct
# 1	0.33333	file variable environment profile question configure specific env configurable write stuff load boot spring location empty app.db.conn rollback finding define
# 2	0.33333	developing await command driver linux list authenticator testing match custom current swift team otps cstring hotfix suggestion framework implemented automation
# 3	0.33333	user authentication run login username password colab java url secret google workflow enable level verify jbutton page image admin disable
# 4	0.33333	config environment release build quot stored stage manifesto approach possibility sound docker snapshot convoluted previous uniquely guideline combine place npm
# 5	0.33333	project property deploy application.properties based thing parameter dev docker inside python application-.properties supply app.web.port useless prod current nodejs working familiar
# 6	0.33333	service process work notebook account successfully find json token private version accept gdrive browser mechanism found page aware build-once yada
# 7	0.33333	quot int amp pas const totp system module png_bytep inputdata crypt appreciated remote static generated make main idea quarkus png_free_all
# 8	0.33333	n't setting django make conf_url server running local root deploying practice devs single problem change nfs/network doe good duplication stored
# 9	0.33333	png_ptr newqrsize qrcode info_ptr string otp row null scale qrsize bool encodedstring ckcrypt method return std strotp uristream base success
# 10	0.33333	host run celery task apply read unit test copy web target give stuck send method wondering store theory ssh imagine
# 11	0.33333	deployment channel firebase backend config manage condition recipe frontend heroku api preview live endpoint remoteconfig figure personal nginx unsupported repository
# 12	0.33333	code set github recovery bar foo file option support simply time hard impossible assistant box locked identical experience coded specifically
# 13	0.33333	configuration production system order vps feature methodology project runtime recommend recommended native cloud step purpose default kind source error platform
# 14	0.33333	variable test_service_port port answer tcp container intellij computed explains documentation serve kubernetes form fclose postgresql limitation helpful type output provide
#
# <100> LL/token: -7.40907
# <110> LL/token: -7.37021
# <120> LL/token: -7.37596
# <130> LL/token: -7.41892
# <140> LL/token: -7.39031
#
# 0	0.33333	dependency isolation adminsiteotprequired difference ensure leak thing otpadminsite import reading understanding development surrounding tool implicit image tf_urls urlpatterns admin class
# 1	0.33333	file variable environment process profile env configure practice hard write boot spring application-.properties app.web.port duplication package create dotenv present order
# 2	0.33333	developing await pas list command authenticator driver linux current python wondering web testing theory progress point day swift team developer
# 3	0.33333	user authentication login username password colab idea page java url workflow enable level jbutton intellij computed authenticate correct part disable
# 4	0.33333	config environment release host build stored stage n't approach time possibility sound place stuck store snapshot convoluted previous back rollback
# 5	0.33333	project property docker deploy run application.properties running parameter specific manifesto configurable based inside empty app.db.conn impossible target nodejs familiar dev
# 6	0.33333	service work file notebook run token account define secret private google stuff load strotp recommended match add gdrive browser machine
# 7	0.33333	quot set amp bool endpoint system location supply appreciated nginx angular design answer rid true png_write_end green png_filter_type_default png_create_info_struct png_structp
# 8	0.33333	django local n't problem devs conf_url single called change runtime accept good coded dev properly redis broker mail changing ignore
# 9	0.33333	png_ptr int newqrsize qrcode info_ptr string otp row null scale method qrsize const encodedstring ckcrypt database return module png_bytep std
# 10	0.33333	celery task question server apply read run unit test deploying copy send methodology custom based give doe architecture method explain
# 11	0.33333	make deployment channel firebase n't manage condition recipe backend frontend find config heroku successfully figure api preview live remoteconfig http
# 12	0.33333	code setting github recovery bar foo option support simply key conf_url assistant box doc totp locked experience mechanism failed working
# 13	0.33333	configuration production system root vps feature twelve-factor recommend native cloud nfs/network finding source platform persisted scaled quick reason exact people
# 14	0.33333	variable test_service_port container port tcp documentation serve explains checked kubernetes exists error red png_write_info user-mode org.postgresql.driver helpful provide desperate great
#
# <150> LL/token: -7.39418
# <160> LL/token: -7.321
# <170> LL/token: -7.38479
# <180> LL/token: -7.37392
# <190> LL/token: -7.34465
#
# 0	0.33333	dependency isolation system import ensure leak otpadminsite reading development surrounding tool native tf_urls nodejs manifesto factor-app understand correct understanding context
# 1	0.33333	file environment variable profile env configure question dev practice hard write stuff boot spring wondering location methodology app.db.conn configurable password
# 2	0.33333	developing await based list command driver linux pas current testing theory doc give swift advance framework implemented language open-source web-app
# 3	0.33333	user account authentication login adminsiteotprequired workflow enable level jbutton page password urlpatterns class authenticate mechanism day part disable directory active
# 4	0.33333	config environment release host build variable stored stage approach read copy possibility sound define docker place stuck store snapshot previous
# 5	0.33333	project property application.properties thing specific deploy run username parameter docker inside python root application-.properties empty supply app.web.port prod add ability
# 6	0.33333	service work notebook token colab json secret private google run local intellij computed gdrive browser create default credential form fclose
# 7	0.33333	quot set authenticator file web std strotp inputdata verify match accept point concept user found png_infopp png_destroy_write_struct png_free_data red png_write_info
# 8	0.33333	n't django celery running deploying devs single called order local change impossible runtime recommend recommended nfs/network step good ci/cd specifically
# 9	0.33333	png_ptr int newqrsize qrcode info_ptr string otp amp row null scale qrsize const bool encodedstring ckcrypt method return module png_bytep
# 10	0.33333	run process task server apply unit test java send method custom back decorator mail automation part-time future factor.net/admin-processes spring-boot one-off
# 11	0.33333	deployment channel firebase config manage condition recipe backend frontend find n't successfully figure preview endpoint remoteconfig http make api heroku
# 12	0.33333	code setting github conf_url make recovery bar foo option support key idea cloud design assistant totp locked simply time duplication
# 13	0.33333	configuration production problem vps twelve-factor identical familiar node team exists kind error feature heroku platform alternative parameter unusable guide pks
# 14	0.33333	variable test_service_port answer port tcp difference load documentation serve container box checked deployed kubernetes properties address provided receives switch manager
#
# <200> LL/token: -7.3397
# <210> LL/token: -7.34304
# [beta: 0.06065]
# <220> LL/token: -7.05756
# <230> LL/token: -7.03431
# [beta: 0.08723]
# <240> LL/token: -6.98625
#
# 0	0.1627	dependency isolation system ensure leak project understanding surrounding tool implicit nodejs achieve concept manifesto factor-app reading development execution section manifest
# 1	0.40373	file n't environment property application.properties profile env question dev practice configurable based hard deploy load run variable application-.properties supply app.web.port
# 2	0.16449	developing await list command driver linux current testing theory based prod design apply pas quot web empty advance appreciated suggestion
# 3	0.26459	user adminsiteotprequired authentication otpadminsite difference import enable level cloud tf_urls urlpatterns class part disable workflow directory active azure blue app/bin/config/application.properties
# 4	0.26217	config environment variable release build host quot stored stage run docker approach n't copy possibility sound read configuration intellij apply
# 5	0.20943	username amp password database jbutton page url configure delete png_byte png_compression_type_default png_set_ihdr png_libpng_ver_string png_create_write_struct png_structp origsecretkey.c_str char redirected authenticates webpage
# 6	0.16732	notebook work token colab user private account service computed authenticate gdrive json browser google authentication verify redirect helpful type launch
# 7	0.26414	quot github support key account authenticator locked day swift team idea answer recommended future sidenote site document move greatly textbook
# 8	0.22796	run celery task django code server devs called unit deploying single follow properly method redis broker main explain decorator mail
# 9	0.05422	quot png_ptr int newqrsize qrcode info_ptr string otp row null scale qrsize const bool encodedstring method return module png_bytep std
# 10	0.29028	make running process step context change impossible runtime java imagine project benefit foot prevent instance feasible hotfix applying logging temporary
# 11	0.10549	quot channel firebase deployment manage condition recipe frontend backend config successfully find n't preview live endpoint remoteconfig figure api heroku
# 12	0.2235	code set conf_url recovery bar foo setting option login assistant box totp experience coded duplication spring user django configure local
# 13	0.15968	configuration production vps deployment wondering set quot feature heroku methodology persisted factor.net/codebase website uniformly server issue deal experienced exercise non-trivial
# 14	0.11513	variable test_service_port port container tcp service documentation root default serve kubernetes admin/management difference override decided dockerfile define place pulled cluster
#
# <250> LL/token: -6.77039
# [beta: 0.09858]
# <260> LL/token: -6.79654
# <270> LL/token: -6.76822
# [beta: 0.10179]
# <280> LL/token: -6.67268
# <290> LL/token: -6.61412
#
# 0	0.0766	dependency isolation project ensure leak understanding system surrounding tool implicit nodejs achieve concept manifesto factor-app reading development execution section manifest
# 1	0.26767	file environment property variable application.properties profile env root deploying configure n't configurable write dev deploy running methodology application-.properties empty supply
# 2	0.07353	developing await quot driver linux list command current testing based apply give pas web advance appreciated suggestion framework automation language
# 3	0.09227	user authentication otpadminsite adminsiteotprequired difference import enable level tf_urls urlpatterns admin class disable workflow directory active azure n't include path
# 4	0.18153	config environment release quot variable host build stored stage run approach read n't file possibility sound docker place stuck order
# 5	0.11704	username java password user jbutton page image url docker qr_mode inputdata.append redirected authenticates webpage verify okta redirect sakila localhost jdbc
# 6	0.08107	notebook work token colab account run service file intellij computed gdrive json browser secret private google user authentication npm type
# 7	0.08139	quot github recovery code set totp option account authenticator assistant box generated support locked key day swift team login idea
# 8	0.10831	celery task django unit test native nfs/network theory system architecture redis server decorator backend mail ignore running scalability recommend recommended
# 9	0.01116	quot png_ptr int newqrsize qrcode info_ptr string otp row null scale amp qrsize const bool encodedstring ckcrypt method return module
# 10	0.11679	run code devs thing make change impossible runtime n't convention app.web.port elaborate faced quarkus benefit break foot shooting prevent instance
# 11	0.03067	quot firebase channel manage condition recipe deployment frontend backend config successfully find n't preview live endpoint remoteconfig figure make api
# 12	0.08159	conf_url setting bar foo code experience coded hard duplication django local set practice resource protected contradictory solution offer writing option
# 13	0.08382	configuration production deployment vps heroku project cloud location local made platform exact love supposed sop document completely declares system-wide spring
# 14	0.06387	variable test_service_port container tcp service port define documentation default serve kubernetes difference override decided point dockerfile installed gateway ambassador istio
#
# [beta: 0.10544]
# <300> LL/token: -6.57667
# <310> LL/token: -6.56688
# [beta: 0.10868]
# <320> LL/token: -6.55684
# <330> LL/token: -6.6278
# [beta: 0.1052]
# <340> LL/token: -6.60273
#
# 0	0.04754	dependency isolation ensure leak understanding system surrounding tool implicit nodejs achieve manifesto factor-app reading development execution section manifest quot enlighten
# 1	0.10543	file environment property profile code env configurable application.properties hard write deploy load configure practice question variable application-.properties empty supply app.web.port
# 2	0.02859	developing await list quot driver linux command current appreciated testing theory based apply pas web scale fine secretkey.c_str crypt generating
# 3	0.03692	adminsiteotprequired authentication otpadminsite difference enable level user tf_urls urlpatterns class import disable workflow directory active azure path admin.site.__class django_otp.admin two_factor.admin
# 4	0.09056	config environment variable release host build quot stored run n't stage file approach read possibility sound define docker place configuration
# 5	0.06136	username password amp java jbutton application.properties page url docker user root configure false qrcode_encodestring retrieving uri crypt part-time authenticates verify
# 6	0.03563	notebook work token colab service file account native cloud intellij gdrive json browser secret private google system user authentication reason
# 7	0.02797	quot github recovery set code option account authenticator assistant box totp support locked key day swift team login problem managed
# 8	0.06333	celery django task running run called unit recommend single follow properly redis broker server explain decorator mail code changing ignore
# 9	0.01123	quot png_ptr int newqrsize qrcode info_ptr string otp row null qrsize scale const bool encodedstring ckcrypt amp method return module
# 10	0.08231	make code n't devs process change impossible runtime nfs/network http contradictory doe thing benefit break shooting instance scaled feasible hotfix
# 11	0.01127	quot firebase channel deployment condition recipe manage frontend backend config successfully find preview live endpoint remoteconfig figure api n't heroku
# 12	0.01982	conf_url bar foo setting experience coded duplication django local redirected back solution offer beautiful writing option pleased super duplicate lastly
# 13	0.03153	project configuration production vps deployment concept kind local feature heroku persisted dependancy docker apps important past conda stumbled isolation node
# 14	0.02264	variable test_service_port tcp port container service documentation default serve kubernetes cluster gateway ambassador istio explains hostnames istead collision naming avoid
#
# <350> LL/token: -6.54817
# [beta: 0.11084]
# <360> LL/token: -6.45217
# <370> LL/token: -6.41018
# [beta: 0.10956]
# <380> LL/token: -6.49416
# <390> LL/token: -6.52677
#
# 0	0.0241	dependency isolation project ensure leak understanding system surrounding tool implicit nodejs concept manifesto factor-app reading development execution section manifest quot
# 1	0.06873	file environment property profile code variable env configurable application.properties hard write deploy stuff load user n't local application-.properties empty supply
# 2	0.0178	developing await command current quot driver linux based pas list testing theory page custom progress apply give web advance appreciated
# 3	0.02702	adminsiteotprequired user authentication otpadminsite difference import enable level tf_urls urlpatterns class part disable workflow directory active azure n't include path
# 4	0.05567	config environment release variable host quot build stored stage file run possibility sound define docker approach read place stuck order
# 5	0.04188	file password username docker system user native cloud nfs/network jbutton amp application.properties url root configure reason exact love scalability recommend
# 6	0.0175	notebook work token colab service account run intellij computed gdrive json browser secret private google authentication helpful type output provide
# 7	0.01386	quot github recovery code set option account authenticator assistant box totp support locked key day swift team login move hint
# 8	0.04211	celery task django run server java properly called redis broker unit decorator mail code changing ignore test running process factor.net/admin-processes
# 9	0.00686	quot png_ptr int newqrsize qrcode info_ptr string otp row null scale amp qrsize const bool encodedstring ckcrypt method return module
# 10	0.07022	make devs simply step code n't change impossible runtime doe run running db_conn benefit break foot shooting prevent instance scaled
# 11	0.00992	quot firebase channel deployment manage condition recipe frontend backend config successfully find n't preview live endpoint remoteconfig figure make api
# 12	0.00675	conf_url bar foo setting experience coded duplication django solution offer writing pleased duplicate lastly good force complicated unnecessarily post put
# 13	0.02688	configuration production vps deployment project problem source question feature heroku platform persisted maintaining deploying issue folk experienced exercise non-trivial turn
# 14	0.01336	variable test_service_port tcp port container documentation service serve kubernetes cluster installed ambassador istio hostnames istead collision naming avoid purpose intentionally
#
# [beta: 0.11166]
# <400> LL/token: -6.47654
# <410> LL/token: -6.39323
# [beta: 0.11261]
# <420> LL/token: -6.40813
# <430> LL/token: -6.45518
# [beta: 0.12127]
# <440> LL/token: -6.38019
#
# 0	0.02508	dependency isolation project ensure leak reading understanding system surrounding tool implicit nodejs achieve concept manifesto factor-app development execution section manifest
# 1	0.02939	file environment property application.properties profile configure n't configurable deploy env variable application-.properties empty supply app.web.port app.db.conn based parameter specific write
# 2	0.02179	developing await quot driver linux list command testing theory based apply pas current advance appreciated framework implemented automation language open-source
# 3	0.017	adminsiteotprequired user authentication otpadminsite difference import enable level tf_urls urlpatterns class disable workflow directory active azure include path admin.site.__class django_otp.admin
# 4	0.05799	config environment variable release host build quot stored file stage approach run copy possibility sound define docker read stuck order
# 5	0.03141	service file username password cloud nfs/network jbutton amp page url authenticate docker system user root reason exact love scalability recommend
# 6	0.01404	notebook work token colab account run intellij computed gdrive json browser secret private google user authentication quot file suggestion npm
# 7	0.01141	quot github recovery set option account authenticator code assistant box totp support locked key day swift team login move hint
# 8	0.02439	celery task django run unit deploying java follow properly redis broker server decorator mail ignore test process temporary factor.net/admin-processes http
# 9	0.00551	quot png_ptr int newqrsize qrcode info_ptr string otp row null scale amp qrsize const bool encodedstring ckcrypt method return module
# 10	0.03473	code make devs running n't change impossible runtime adding http changing production benefit break foot shooting prevent instance scaled feasible
# 11	0.00543	quot firebase channel deployment manage condition recipe frontend backend config successfully find n't preview live endpoint remoteconfig figure api heroku
# 12	0.01953	conf_url bar foo setting code experience coded hard duplication django local file solution offer beautiful writing option pleased super duplicate
# 13	0.01347	configuration production vps deployment project feature heroku platform persisted call syntax issue deal experienced wondering exercise non-trivial turn quickly regenerated
# 14	0.00816	variable test_service_port tcp port container documentation service serve kubernetes question automate cluster installed gateway ambassador istio explains hostnames istead collision
#
# <450> LL/token: -6.40881
# [beta: 0.12171]
# <460> LL/token: -6.31004
# <470> LL/token: -6.38655
# [beta: 0.11953]
# <480> LL/token: -6.32461
# <490> LL/token: -6.33588
#
# 0	0.01954	dependency isolation project ensure leak understanding system surrounding tool implicit nodejs achieve concept manifesto factor-app reading development execution section manifest
# 1	0.02409	file environment property profile variable configurable application.properties deploy run env application-.properties empty supply app.web.port app.db.conn based parameter thing specific inside
# 2	0.01393	developing await quot driver linux list command testing theory based apply pas current advance appreciated suggestion framework implemented automation language
# 3	0.01183	adminsiteotprequired user authentication otpadminsite difference import enable level tf_urls urlpatterns class disable workflow directory active include path admin.site.__class django_otp.admin two_factor.admin
# 4	0.04032	config environment variable release host build quot stored run n't stage approach read question file copy configuration possibility sound docker
# 5	0.03122	file password username url system user root native cloud nfs/network jbutton amp application.properties page assistant support docker login configure reason
# 6	0.01382	notebook token colab service work account user file intellij computed define gdrive json browser secret private google authentication default npm
# 7	0.00931	quot github recovery code set option account authenticator box totp locked key day swift team login move hint design textbook
# 8	0.02106	celery task django run unit server setting test process java properly send called method redis broker decorator mail code ignore
# 9	0.00699	quot png_ptr int newqrsize qrcode info_ptr string otp row null scale amp qrsize const bool encodedstring ckcrypt method return module
# 10	0.00962	devs code change impossible runtime make n't benefit break foot shooting prevent instance scaled feasible hotfix quick applying logging temporary
# 11	0.00459	quot firebase channel deployment manage condition recipe frontend backend config successfully find n't preview live endpoint remoteconfig figure make api
# 12	0.00463	conf_url bar foo setting file code experience coded hard duplication django local solution offer beautiful writing option pleased super duplicate
# 13	0.00905	configuration production vps project process feature heroku platform persisted init.json unstable issue deal folk experienced exercise non-trivial turn quickly regenerated
# 14	0.00463	variable test_service_port tcp port container documentation service serve kubernetes cluster installed gateway ambassador istio explains hostnames istead collision naming avoid
#
# [beta: 0.1197]
# <500> LL/token: -6.36145
# <510> LL/token: -6.35915
# [beta: 0.12115]
# <520> LL/token: -6.32755
# <530> LL/token: -6.31206
# [beta: 0.12543]
# <540> LL/token: -6.34145
#
# 0	0.01389	dependency isolation project ensure leak understanding system surrounding tool implicit nodejs achieve concept manifesto factor-app reading development execution section manifest
# 1	0.01984	file environment property profile variable configurable application.properties deploy boot env application-.properties empty supply app.web.port app.db.conn based parameter specific write dev
# 2	0.00792	developing await quot driver linux list command testing theory based apply pas current advance appreciated suggestion framework implemented automation language
# 3	0.01769	adminsiteotprequired user authentication otpadminsite difference import enable level tf_urls urlpatterns class disable workflow directory active azure include path admin.site.__class django_otp.admin
# 4	0.03236	config environment variable release host quot build stored run n't stage approach read copy possibility sound define docker place setting
# 5	0.01804	file username password native cloud nfs/network jbutton amp application.properties page url docker system user root configure reason exact love scalability
# 6	0.01379	notebook service work token colab json account run computed gdrive browser secret private google user authentication default file helpful npm
# 7	0.0098	quot github recovery code set option account authenticator assistant box totp support locked key day swift team login move hint
# 8	0.01392	celery task django called java properly run redis broker unit server decorator mail code ignore test running process factor.net/admin-processes http
# 9	0.00388	quot png_ptr int newqrsize qrcode info_ptr string otp row null scale amp qrsize const bool encodedstring ckcrypt method return module
# 10	0.00967	devs code change impossible runtime make n't production benefit break foot shooting prevent instance scaled feasible hotfix quick applying logging
# 11	0.00388	quot firebase channel deployment manage condition recipe frontend backend config successfully find n't preview live endpoint remoteconfig figure make api
# 12	0.00403	conf_url bar foo file setting code experience coded hard duplication django local solution offer beautiful writing option pleased super duplicate
# 13	0.00387	configuration production vps deployment project file feature heroku platform persisted iphone issue deal folk experienced wondering exercise non-trivial turn quickly
# 14	0.00767	variable test_service_port tcp port container documentation service serve kubernetes cluster installed gateway ambassador istio explains hostnames istead collision naming avoid
#
# <550> LL/token: -6.32649
# [beta: 0.11973]
# <560> LL/token: -6.35448
# <570> LL/token: -6.36022
# [beta: 0.1191]
# <580> LL/token: -6.3181
# <590> LL/token: -6.33631
#
# 0	0.01155	dependency isolation ensure leak project understanding system surrounding tool implicit nodejs achieve concept manifesto factor-app reading execution section manifest quot
# 1	0.01543	file property environment application.properties profile variable configurable env n't application-.properties empty supply app.web.port app.db.conn based parameter specific write dev deploy
# 2	0.01321	developing await quot driver linux list command testing theory based apply pas current advance appreciated suggestion framework implemented automation language
# 3	0.0077	adminsiteotprequired user authentication otpadminsite difference import enable level tf_urls urlpatterns class disable workflow directory active azure include path admin.site.__class django_otp.admin
# 4	0.03271	config environment variable release host build quot stored file stage approach run possibility sound define docker read place stuck order
# 5	0.01718	file username password native cloud nfs/network jbutton amp page url docker system user root configure reason exact love scalability recommend
# 6	0.0116	notebook work token colab account run service quot computed gdrive json browser secret private google user authentication file helpful type
# 7	0.00758	quot github recovery code set option account authenticator assistant box totp support locked key day swift team login move hint
# 8	0.0188	celery task django run called unit server java follow properly redis broker decorator mail code ignore test running process factor.net/admin-processes
# 9	0.00372	quot png_ptr int newqrsize qrcode info_ptr string otp row null scale amp qrsize const bool encodedstring ckcrypt method return module
# 10	0.00931	code devs change impossible runtime make n't benefit break foot shooting prevent instance scaled feasible hotfix quick applying logging temporary
# 11	0.0092	quot firebase channel deployment manage condition recipe frontend backend config successfully find n't preview live endpoint remoteconfig figure make api
# 12	0.0037	conf_url bar foo setting file code experience coded hard duplication django local solution offer beautiful writing option pleased super duplicate
# 13	0.0037	configuration production vps deployment project heroku platform persisted issue deal experienced exercise non-trivial turn quickly regenerated credential problem disappearance unexpected
# 14	0.00553	variable test_service_port tcp port container documentation service serve deploying kubernetes cluster installed gateway ambassador istio explains hostnames istead collision naming
#
# [beta: 0.12792]
# <600> LL/token: -6.30389
# <610> LL/token: -6.33352
# [beta: 0.12338]
# <620> LL/token: -6.33777
# <630> LL/token: -6.31678
# [beta: 0.12091]
# <640> LL/token: -6.33747
#
# 0	0.01001	dependency isolation project ensure leak understanding system surrounding tool implicit nodejs achieve concept manifesto factor-app reading development execution section manifest
# 1	0.02367	file environment variable property profile n't env project configurable application.properties dev deploy configure practice application-.properties empty supply app.web.port app.db.conn based
# 2	0.00837	developing await quot driver linux list command testing theory based apply pas current advance appreciated suggestion framework implemented automation language
# 3	0.00977	adminsiteotprequired user authentication otpadminsite difference import enable level tf_urls urlpatterns class disable workflow directory active azure include path admin.site.__class django_otp.admin
# 4	0.02458	config environment release host quot build variable run stored stage file approach read step possibility sound define docker place stuck
# 5	0.01166	file username password user native cloud nfs/network jbutton amp application.properties page image url docker system root service configure cstring supplied
# 6	0.01139	notebook token colab work account service intellij computed gdrive json browser secret private google user authentication file npm output provide
# 7	0.00662	quot github recovery code set option account authenticator assistant box totp support locked key day swift team login move hint
# 8	0.01162	celery task django run called server java properly redis broker unit decorator mail code ignore test running process factor.net/admin-processes http
# 9	0.00325	quot png_ptr int newqrsize qrcode info_ptr string otp row null scale amp qrsize const bool encodedstring ckcrypt method return module
# 10	0.00324	devs code change impossible runtime make n't benefit break foot prevent instance scaled feasible quick applying logging temporary preventing recommend
# 11	0.00485	quot firebase channel deployment manage condition recipe frontend backend config successfully find n't preview live endpoint remoteconfig figure make api
# 12	0.00324	conf_url bar foo setting code coded hard duplication django local solution offer beautiful writing pleased super duplicate experience good force
# 13	0.00327	configuration production deployment vps feature heroku platform persisted issue deal folk experienced wondering exercise non-trivial turn quickly credential present disappearance
# 14	0.00489	variable test_service_port tcp port container documentation service serve kubernetes cluster installed gateway ambassador istio explains hostnames istead collision naming avoid
#
# <650> LL/token: -6.32154
# [beta: 0.11993]
# <660> LL/token: -6.31555
# <670> LL/token: -6.32794
# [beta: 0.11797]
# <680> LL/token: -6.34467
# <690> LL/token: -6.36525
#
# 0	0.01124	dependency isolation project ensure leak understanding system surrounding tool implicit nodejs achieve concept manifesto factor-app reading development execution section manifest
# 1	0.00997	file environment property profile configurable application.properties env variable application-.properties empty supply app.web.port app.db.conn based parameter specific dev deploy create load
# 2	0.00632	developing await quot driver linux list command testing theory based apply pas current advance appreciated suggestion framework implemented automation language
# 3	0.01099	authentication enable level user make disable workflow login directory active azure hint asks passcoded pick submit microsoft manager support profile
# 4	0.02831	config environment variable release quot host build stored file n't stage approach read deploy run copy possibility sound define docker
# 5	0.01762	file username amp password system native cloud nfs/network jbutton application.properties page url docker user root configure alpha green png_init_io size
# 6	0.00938	notebook work token colab service account run computed gdrive json browser secret private google user authentication default file helpful npm
# 7	0.0064	quot github recovery code set option account authenticator assistant box totp locked key day swift team move greatly design textbook
# 8	0.01439	celery task django run called unit server running impossible java single properly redis broker explain decorator mail code changing ignore
# 9	0.00313	quot png_ptr int newqrsize qrcode info_ptr string otp row null scale qrsize const bool encodedstring ckcrypt amp method return module
# 10	0.00622	adminsiteotprequired code devs otpadminsite difference import n't change runtime tf_urls urlpatterns thing class make benefit foot prevent instance scaled hotfix
# 11	0.00467	quot firebase channel deployment manage condition recipe frontend backend config successfully find n't preview live endpoint remoteconfig figure make api
# 12	0.00465	conf_url bar foo setting file code experience coded hard duplication django local solution offer beautiful writing option pleased super duplicate
# 13	0.00312	configuration production vps deployment project file feature heroku platform persisted deal folk experienced exercise non-trivial turn quickly regenerated credential problem
# 14	0.00466	variable test_service_port tcp port container documentation service serve kubernetes cluster installed gateway ambassador istio explains hostnames istead collision naming avoid
#
# [beta: 0.1176]
# <700> LL/token: -6.33716
# <710> LL/token: -6.35407
# [beta: 0.11868]
# <720> LL/token: -6.31794
# <730> LL/token: -6.35256
# [beta: 0.12268]
# <740> LL/token: -6.3392
#
# 0	0.00998	dependency isolation project ensure leak understanding system surrounding tool implicit nodejs achieve concept manifesto factor-app reading development execution section manifest
# 1	0.01647	file environment property profile django n't variable configurable application.properties write dev deploy env application-.properties empty supply app.web.port app.db.conn based parameter
# 2	0.00647	developing await command quot driver linux list testing theory based apply pas current advance appreciated suggestion framework implemented automation language
# 3	0.00643	authentication login enable level user make disable workflow directory active azure idea move googled desperate apparently asks end generated longer
# 4	0.03093	config environment release host variable build quot stored file stage run approach read n't copy configuration possibility sound define docker
# 5	0.00997	file password native cloud nfs/network username amp application.properties docker system root configure supplied reason exact love scalability recommend recommended people
# 6	0.00815	notebook work token colab account service intellij computed gdrive json browser secret private google user authentication run file helpful type
# 7	0.00967	quot github recovery code set option account authenticator assistant box totp support key day swift team hint greatly design textbook
# 8	0.0082	celery task django run server code java redis broker unit decorator mail ignore test running process line accessed deploy-many api_url
# 9	0.00321	quot png_ptr int newqrsize qrcode info_ptr string otp row null scale amp qrsize const bool encodedstring ckcrypt method return module
# 10	0.00968	adminsiteotprequired code devs otpadminsite difference import n't change impossible runtime tf_urls urlpatterns thing class make benefit break foot shooting prevent
# 11	0.00324	quot firebase channel deployment manage condition recipe frontend backend config successfully find n't preview live endpoint remoteconfig figure make api
# 12	0.00478	conf_url bar foo setting user jbutton page experience coded url duplication code local redirected authenticates verify okta redirect username java
# 13	0.00797	configuration production vps deployment feature project heroku platform issue deal folk experienced wondering non-trivial turn quickly regenerated credential present disappearance
# 14	0.01109	variable test_service_port tcp port container service documentation default kubernetes difference decided dockerfile reading cluster installed gateway ambassador istio explains hostnames
#
# <750> LL/token: -6.38767
# [beta: 0.12108]
# <760> LL/token: -6.34938
# <770> LL/token: -6.39715
# [beta: 0.11947]
# <780> LL/token: -6.3563
# <790> LL/token: -6.31749
#
# 0	0.01179	dependency isolation ensure leak project reading understanding system surrounding tool implicit nodejs achieve concept manifesto factor-app development execution section manifest
# 1	0.01856	file environment property profile variable configurable application.properties deploy env application-.properties empty supply app.web.port app.db.conn based parameter specific write dev follow
# 2	0.00671	developing await quot driver linux list command testing theory based apply pas current advance appreciated suggestion framework implemented automation language
# 3	0.00828	user authentication enable level make disable workflow directory active azure auth mad luck guide pick locked profile sign part api
# 4	0.02854	config environment variable release host quot build stored n't stage run read copy configuration possibility sound define docker approach stuck
# 5	0.01678	file username password native cloud nfs/network jbutton amp application.properties page url docker correct system user root service configure png_free_all png_interlace_none
# 6	0.01008	notebook work token colab account service intellij computed gdrive json browser secret private google user authentication run file helpful npm
# 7	0.01008	quot github recovery code set option account authenticator assistant box totp support key day swift team login move hint greatly
# 8	0.01323	celery task django run called unit server java properly redis broker decorator mail code ignore test deploying running process factor.net/admin-processes
# 9	0.0033	quot png_ptr int newqrsize qrcode info_ptr string otp row null scale amp qrsize const bool encodedstring ckcrypt method return module
# 10	0.01009	adminsiteotprequired code devs otpadminsite difference import n't change impossible runtime tf_urls urlpatterns thing class make benefit break foot shooting prevent
# 11	0.0033	quot firebase channel deployment manage condition recipe frontend backend config successfully find n't preview live endpoint remoteconfig figure make api
# 12	0.0083	conf_url bar foo setting file code experience coded hard duplication django local solution offer beautiful writing option pleased super duplicate
# 13	0.00492	configuration production project vps local deployment feature heroku platform persisted dependancies case working ci/cd deal experienced wondering exercise turn quickly
# 14	0.00824	variable test_service_port tcp port container documentation service serve kubernetes cluster installed gateway ambassador istio explains hostnames istead collision naming avoid
#
# [beta: 0.11833]
# <800> LL/token: -6.3413
# <810> LL/token: -6.34413
# [beta: 0.11932]
# <820> LL/token: -6.28791
# <830> LL/token: -6.29876
# [beta: 0.12685]
# <840> LL/token: -6.28823
#
# 0	0.01171	dependency isolation project ensure leak understanding system surrounding tool implicit nodejs achieve concept manifesto factor-app reading development execution section manifest
# 1	0.00674	file environment property profile configurable application.properties env variable application-.properties empty supply app.web.port app.db.conn based parameter deploy create load boot spring
# 2	0.00822	developing await quot driver linux list command testing theory based apply pas current qr_mode advance appreciated suggestion framework implemented automation
# 3	0.0049	authentication enable level user disable workflow directory active azure profile sign part make api graph console customer login implementing business
# 4	0.0265	config environment variable release host build quot file stored stage run n't docker approach read copy possibility sound define place
# 5	0.01521	file username password native cloud nfs/network jbutton amp application.properties page url docker system user root configure reason exact love scalability
# 6	0.01323	notebook work token colab account run service intellij computed gdrive json browser secret private google user authentication file helpful npm
# 7	0.00827	quot github recovery code set option account authenticator assistant box totp support locked key day swift team login move hint
# 8	0.01528	celery task django run unit server java follow properly called redis broker decorator mail code ignore test running process factor.net/admin-processes
# 9	0.00488	quot png_ptr int newqrsize qrcode info_ptr string otp row null scale amp qrsize const bool encodedstring ckcrypt method return module
# 10	0.00989	adminsiteotprequired code devs otpadminsite difference import n't change impossible runtime tf_urls urlpatterns thing class make benefit break foot shooting prevent
# 11	0.00328	quot firebase channel deployment manage condition recipe frontend backend config successfully find n't preview live endpoint remoteconfig figure make api
# 12	0.0033	conf_url bar foo setting file code experience coded hard duplication django local solution offer beautiful writing option pleased super duplicate
# 13	0.00327	configuration production vps deployment project question feature heroku platform methodology persisted dev/qa/prod specific deal folk wondering exercise non-trivial turn quickly
# 14	0.00327	variable test_service_port tcp port container documentation service serve kubernetes cluster installed gateway ambassador istio explains hostnames istead collision naming avoid
#
# <850> LL/token: -6.28809
# [beta: 0.12504]
# <860> LL/token: -6.30542
# <870> LL/token: -6.30664
# [beta: 0.12364]
# <880> LL/token: -6.29581
# <890> LL/token: -6.32124
#
# 0	0.00939	dependency isolation project ensure leak understanding system surrounding tool implicit nodejs achieve concept manifesto factor-app reading development execution section manifest
# 1	0.01223	file environment property profile variable configurable application.properties deploy env application-.properties empty supply app.web.port app.db.conn based parameter specific dev follow create
# 2	0.00779	developing await command quot driver linux list testing theory progress based apply pas current advance appreciated suggestion framework implemented automation
# 3	0.00457	authentication enable level user intellij computed disable workflow directory active azure idea helpful type provide script debug nunjucks sop provided
# 4	0.0247	config environment release variable host build quot stored run n't stage approach read file copy configuration possibility sound define docker
# 5	0.01103	file username password native cloud nfs/network jbutton amp application.properties page image url docker system user root configure module png_infop reason
# 6	0.0108	notebook work token colab account service gdrive json browser secret private google user authentication file npm launch receives respective mount
# 7	0.00772	quot github recovery code set option account authenticator assistant box totp support locked key day swift team login move hint
# 8	0.00939	celery task django run unit server java properly called redis broker decorator mail code ignore test running process factor.net/admin-processes http
# 9	0.00306	quot png_ptr int newqrsize qrcode info_ptr string otp row null scale amp qrsize const bool encodedstring ckcrypt method return png_bytep
# 10	0.00771	adminsiteotprequired code devs otpadminsite difference import change impossible runtime tf_urls urlpatterns thing class make n't benefit break foot shooting prevent
# 11	0.00306	quot firebase channel deployment manage condition recipe frontend backend config successfully find n't preview live endpoint remoteconfig figure make api
# 12	0.00756	conf_url bar foo setting file code experience coded hard duplication django local solution offer beautiful writing option pleased super duplicate
# 13	0.00307	configuration production vps deployment project file feature heroku platform variable issue deal folk experienced exercise non-trivial turn quickly regenerated credential
# 14	0.00611	variable test_service_port tcp port container service documentation default serve kubernetes difference database cluster installed gateway ambassador istio explains hostnames istead
#
# [beta: 0.12038]
# <900> LL/token: -6.31091
# <910> LL/token: -6.32756
# [beta: 0.12098]
# <920> LL/token: -6.31847
# <930> LL/token: -6.33902
# [beta: 0.12562]
# <940> LL/token: -6.28599
#
# 0	0.00888	dependency isolation project ensure leak understanding system surrounding tool implicit nodejs achieve concept manifesto factor-app reading development execution section manifest
# 1	0.0163	file environment variable property profile configurable application.properties deploy run env n't application-.properties empty supply app.web.port app.db.conn based parameter specific write
# 2	0.00736	developing await quot driver linux list command testing theory based design apply pas current advance appreciated suggestion framework implemented automation
# 3	0.00292	authentication enable level user disable workflow directory active azure profile sign part make api graph console customer login implementing business
# 4	0.02308	config environment release quot host build variable stored run stage file configuration approach n't possibility sound define docker read place
# 5	0.01328	file username password native cloud nfs/network jbutton amp application.properties page url docker system user root configure reason exact love scalability
# 6	0.00867	notebook token colab work account service intellij computed gdrive json browser secret private google user authentication file helpful npm output
# 7	0.0073	quot github recovery code set option account authenticator assistant box totp support locked key day swift team login move greatly
# 8	0.01303	celery django task unit code single properly run redis broker server explain decorator mail ignore test running runtime adding release
# 9	0.0029	quot png_ptr int newqrsize qrcode info_ptr string otp row null scale amp qrsize const bool encodedstring ckcrypt method return module
# 10	0.00883	adminsiteotprequired devs otpadminsite difference import code n't change impossible java tf_urls urlpatterns admin thing class make run process benefit break
# 11	0.00432	quot firebase channel deployment manage condition recipe frontend backend config successfully find n't preview live endpoint remoteconfig figure make api
# 12	0.00431	conf_url bar foo setting file code experience coded hard duplication django local solution offer beautiful writing option pleased super duplicate
# 13	0.00289	configuration production vps deployment project feature heroku platform persisted issue deal folk exercise non-trivial turn quickly regenerated credential disappearance unexpected
# 14	0.00289	variable test_service_port tcp port container documentation service serve kubernetes cluster installed gateway ambassador istio explains hostnames istead collision naming avoid
#
# <950> LL/token: -6.31639
# [beta: 0.1242]
# <960> LL/token: -6.30547
# <970> LL/token: -6.31754
# [beta: 0.12475]
# <980> LL/token: -6.32605
# <990> LL/token: -6.27191
#
# 0	0.01021	dependency isolation project ensure leak understanding system surrounding tool implicit nodejs achieve concept manifesto factor-app reading development execution section manifest
# 1	0.01785	file environment variable n't property profile env practice configurable application.properties hard write dev deploy make run local question project application-.properties
# 2	0.00723	developing await quot driver linux list command testing theory based apply pas current advance appreciated suggestion framework implemented automation language
# 3	0.00713	user authentication enable level jbutton page disable workflow login directory active azure redirected authenticates webpage verify redirect username java password
# 4	0.0241	config environment release host build quot variable stored stage possibility sound docker approach read stuck run file apply snapshot convoluted
# 5	0.00732	file recommended native cloud nfs/network username amp application.properties password docker system root running configure quick reason exact love scalability recommend
# 6	0.00581	notebook work token colab account run service intellij computed gdrive json browser private google user authentication file npm type launch
# 7	0.00582	quot github recovery code set option account authenticator assistant box totp support locked key day swift team login move hint
# 8	0.00882	celery django task run called unit server properly redis broker decorator mail code ignore test running okta single read systemd
# 9	0.00427	quot png_ptr int newqrsize qrcode info_ptr string otp row null scale amp qrsize const bool encodedstring ckcrypt method return module
# 10	0.01011	adminsiteotprequired code devs otpadminsite difference import n't change impossible runtime java tf_urls urlpatterns admin thing class make run process benefit
# 11	0.00287	quot firebase channel deployment manage condition recipe frontend backend config successfully find n't preview live endpoint remoteconfig figure make api
# 12	0.00286	conf_url bar foo setting code experience coded duplication django solution offer beautiful writing option pleased super duplicate lastly force complicated
# 13	0.00286	configuration production vps quot config deployment feature heroku platform persisted issue deal folk experienced wondering exercise non-trivial turn quickly regenerated
# 14	0.00286	variable test_service_port tcp port container documentation service serve kubernetes cluster installed gateway ambassador istio explains hostnames istead collision naming avoid
#
# [beta: 0.11992]
# <1000> LL/token: -6.30864
#
# Total time: 1 seconds

# %% [markdown]
# ## Parse results
#
# The following script parse the mallet output and place all questions from the same topic into one file. Resulting in one file per document.

# %%
from parse_topics_composition import parse_topics
from unite_topics_in_one_file import unite_questions_documents_by_topic

print('Parsing topics...')
parse_topics()
print('Uniting questions by topic...')
unite_questions_documents_by_topic()
print('Done!')
# Out:
# Parsing topics...
# Uniting questions by topic...
# Folder ./output/topics created!
# Done!
